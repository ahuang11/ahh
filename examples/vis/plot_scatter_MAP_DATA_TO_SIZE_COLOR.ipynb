# %%
from ahh import exp, ext, vis
import matplotlib.pyplot as plt
import numpy as np

# %%
x, y = exp.arr_1d(xy=True)

# %%
s = [1 * 2**n for n in x]
c = range(0, 15)

# %%
ax =  vis.plot_scatter(x, y, s=s) # map data to size

# %%
ax = vis.plot_scatter(x, y, c=c, cmap='inferno_r', interval=3) # map data to color

# %%
ax = vis.plot_scatter(x, y, s=s, c=c, cmap='inferno_r', interval=3) # map data to color and size
